# %%
x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![dog.jpg](attachment:e3cc950b-8255-4b43-8d57-a8d8a528e877.jpg)

# %%
y = 1

y *= 6
y *= 5
y *= 4
y *= 3
y *= 2
y *= 1

print(y)
# Out:
# 720

# %%
h = 6.62607015*10**(-34)
f= 2.42*10**28
c= 3*10**8
λ = c/f
E = h*(c/λ)

print(E)
# Out:
# 1.6035089762999996e-05

# %%
G = 6.67408*10**(-11)
M1 = 7.342*10**22
M2 = 5.9722*10**24
r = 385000600
F = (G*M1*M2)/r**2
print(F)
# Out:
# 1.9743189716506414e+20
